# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import cv2
import numpy
import math
import random

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
im0 = numpy.ndarray(shape=(50,50))
for i in range(im0.shape[0]):
    for j in range(im0.shape[1]):
        im0[i][j] = random.randint(0, 256)
plt.imshow(im0, cmap = plt.get_cmap('gray'))

# %%
im0fft = numpy.fft.fft2(im0)

im0fft_gray = numpy.ndarray(shape=im0fft.shape, dtype=float_)
for i in range(-im0.shape[0]//2, im0.shape[0]//2):
    for j in range(-im0.shape[1]//2, im0.shape[1]//2):         
        im0fft_gray[i][j] = numpy.abs(im0fft[i][j])
        if i == 0 and j == 0:
            im0fft_gray[i][j] = 0

plt.imshow(im0fft_gray, cmap = plt.get_cmap('gray'))
# Out:
# [[    0.          2030.81660973  3062.31227283 ...,  4771.47333345
#    3062.31227283  2030.81660973]
#  [ 5211.40263722  3925.51758524   428.11986495 ...,  2354.1163192
#    1646.25836325  2002.48000652]
#  [ 1067.21055962  3032.23971833  3646.53935774 ...,  4195.56265834
#     811.41080481  3387.53848403]
#  ...,
#  [ 6217.80568253  4955.7344601   1123.54408066 ...,  5801.85099657
#     742.29038999  6752.11303358]
#  [ 1067.21055962  3387.53848403   811.41080481 ...,   746.43620396
#    3646.53935774  3032.23971833]
#  [ 5211.40263722  2002.48000652  1646.25836325 ...,   810.51190757
#     428.11986495  3925.51758524]]

# %%
b = 1.8
for i in range(-im0.shape[0]//2, im0.shape[0]//2):
    for j in range(-im0.shape[1]//2, im0.shape[1]//2):        
        if not i*j == 0:
            im0fft[i][j] *= 1/(i+j)
            
im0fft_gray = numpy.ndarray(shape=im0fft.shape, dtype=float_)
for i in range(-im0.shape[0]//2, im0.shape[0]//2):
    for j in range(-im0.shape[1]//2, im0.shape[1]//2):         
        im0fft_gray[i][j] = numpy.abs(im0fft[i][j])
        if i == 0 and j == 0:
            im0fft_gray[i][j] = 0

plt.imshow(im0fft_gray, cmap = plt.get_cmap('gray'))

# %%
im1 = numpy.fft.ifft2(im0fft)

im1_gray = numpy.ndarray(shape=im1.shape, dtype=float_)
for i in range(-im0.shape[0]//2, im0.shape[0]//2):
    for j in range(-im0.shape[1]//2, im0.shape[1]//2): 
        im1_gray[i][j] = numpy.abs(im1[i][j])


plt.imshow(im1_gray, cmap = plt.get_cmap('gray'))
